# %%
import generator_utils as utils


import sys
sys.path.insert(1, '../')
import ressources as rss
import preprocessing as pp

# %%
# initialisation des variables globales
rss.init()

# %%
# Liste de toutes les fonts disponibles
fonts = pp.get_files('fonts', ext='', sub=False) # ['CollectionNewStyle', 'Best Soullmate', 'Brigidha SIgnature', 'Witches Friend Display']

# Generation des images : nb_images * nombre de fonts
nombre_total_image = 500

nb_img_per_font = nombre_total_image // len(fonts)
for font in fonts:
    for i in range(0,nb_img_per_font):
        utils.gen_word(font)

# %%
### UNIQUEMENT POUR VISU - appercu des mots générés

utils.show_some_images(pp.get_files('word_images', ext='png', sub=False))

    # plt.title('True Label: ' + str(y_test[i]) \
    #         + '\n' + 'Prediction: '+ str(predicted_transcriptions[i])) #\
# Out:
# Total files :  578
